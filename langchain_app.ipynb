# %%
# Import libraries
import os
from langchain_openai import OpenAI  # updated package

# Set your OpenAI API key (replace with your key)
os.environ["OPENAI_API_KEY"] = "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"

# Initialize the LLM
llm = OpenAI(
    model_name="gpt-3.5-turbo",  # or "gpt-4"
    temperature=0.7
)

# Use the new .invoke() method
response = llm.invoke("I want to open a restaurant for Italian food. Suggest a fancy name for it.")

# Print the response
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 15
#       9 llm = OpenAI(
#      10     model_name="gpt-3.5-turbo",  # or "gpt-4"
#      11     temperature=0.7
#      12 )
#      14 # Use the new .invoke() method
# ---> 15 response = llm.invoke("I want to open a restaurant for Italian food. Suggest a fancy name for it.")
#      17 # Print the response
#      18 print(response)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)
#     385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
# ...
