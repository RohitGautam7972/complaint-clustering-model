# %%
import pandas as pd
import numpy as np
import string
import itertools
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import yake
print("done")
# Out:
# done

# %%
import csv

input_file = 'clustering_data.csv'   # your original CSV
output_file = 'clustering_data_clean.csv'  # cleaned CSV

with open(input_file, 'r', encoding='utf-8') as infile, \
     open(output_file, 'w', encoding='utf-8', newline='') as outfile:
    
    reader = csv.reader(infile)
    writer = csv.writer(outfile, quoting=csv.QUOTE_ALL)
    
    # Read header
    try:
        header = next(reader)
    except StopIteration:
        print("CSV is empty!")
        exit()
    
    if len(header) != 4:
        print(f"Warning: Header has {len(header)} columns, expected 4")
    
    writer.writerow(header)  # write header to cleaned file
    
    for row in reader:
        # Skip empty rows
        if not row or all(cell.strip() == '' for cell in row):
            continue
        
        # Only keep rows with exactly 4 columns
        if len(row) != 4:
            print(f"Skipping malformed row: {row}")
            continue
        
        # Write row safely (wrap text in quotes)
        writer.writerow(row)

print(f"Cleaned CSV saved as: {output_file}")
# Out:
# Skipping malformed row: ['5', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-08-17']
# Skipping malformed row: ['12', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-08-28']
# Skipping malformed row: ['21', 'Unhygienic washrooms', ' cleaning staff rarely attends.', 'Hostel', '2025-08-03']
# Skipping malformed row: ['26', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-08-10']
# Skipping malformed row: ['31', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-07-16']
# Skipping malformed row: ['42', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-08-05']
# Skipping malformed row: ['47', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-08-21']
# Skipping malformed row: ['56', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-08-07']
# Skipping malformed row: ['60', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-07-26']
# Skipping malformed row: ['75', 'Door locks are faulty', ' posing security risks.', 'Hostel', '2025-08-23']
# Skipping malformed row: ['80', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-07-25']
# Skipping malformed row: ['87', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-08-03']
# Skipping malformed row: ['106', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-08-05']
# Skipping malformed row: ['113', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-08-04']
# Skipping malformed row: ['124', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-07-31']
# Skipping malformed row: ['136', 'The water supply is highly irregular', ' especially in the mornings.', 'Maintenance', '2025-07-28']
# Skipping malformed row: ['142', "Doors don't lock properly", ' posing security risks.', 'Hostel', '2025-07-30']
# Skipping malformed row: ['151', 'The HVAC system in the main library often fails', ' leaving students uncomfortable during study hours.', 'Maintenance', '2025-08-15']
# Skipping malformed row: ['156', 'Some lecturers have canceled multiple sessions citing personal reasons', ' affecting syllabus coverage.', 'Faculty', '2025-08-12']
# Skipping malformed row: ['158', 'Sports equipment storage rooms are often left unlocked', ' causing security concerns.', 'Sports', '2025-07-28']
# Skipping malformed row: ['160', 'Faculty feedback on assignments lacks detail', ' which makes it hard to improve subsequent work.', 'Faculty', '2025-07-22']
# Skipping malformed row: ['161', 'Mess staff hygiene standards are worrying', ' raising concerns about food safety.', 'Hostel', '2025-08-17']
# Skipping malformed row: ['163', 'The air conditioning in several lecture halls is not functioning properly', ' causing discomfort.', 'Maintenance', '2025-07-27']
# Skipping malformed row: ['165', 'Hostel laundry facilities are insufficient for the number of residents', ' leading to delays.', 'Hostel', '2025-07-24']
# Skipping malformed row: ['167', 'The common room lights flicker constantly', ' disturbing students trying to relax.', 'Maintenance', '2025-08-10']
# Skipping malformed row: ['173', 'Mess menu lacks variety', ' and there is little consideration for dietary restrictions.', 'Hostel', '2025-07-28']
# Skipping malformed row: ['174', 'Sports field floodlights are broken', ' restricting evening practice times.', 'Sports', '2025-08-08']
# Skipping malformed row: ['175', 'Frequent water leaks in hostel block C', ' causing wet floors and hazards.', 'Maintenance', '2025-07-21']
# Skipping malformed row: ['177', 'Insect infestations reported in the mess area', ' hygiene needs immediate attention.', 'Hostel', '2025-08-03']
# Skipping malformed row: ['191', 'Maintenance requests take weeks to be addressed', ' especially plumbing issues.', 'Maintenance', '2025-08-05']
# Skipping malformed row: ['203', 'Mess food has become repetitive and tasteless', ' reducing student satisfaction significantly.', 'Hostel', '2025-09-07']
# Skipping malformed row: ['205', 'Poor lighting in several corridors is causing accidents late at night', ' urgent maintenance needed.', 'Maintenance', '2025-08-31']
# Skipping malformed row: ['207', 'Hostel internet connection drops frequently during late hours', ' disrupting study sessions.', 'Hostel', '2025-08-29']
# Skipping malformed row: ['209', 'Washing machine in hostel laundry room is frequently out of order', ' increasing waiting times.', 'Maintenance', '2025-09-04']
# Skipping malformed row: ['211', 'Unsanitary conditions in the mess reported by numerous students', ' urgent cleaning needed.', 'Hostel', '2025-09-08']
# Skipping malformed row: ['216', 'The football field lacks proper line markings', ' which affects official matches.', 'Sports', '2025-09-06']
# Skipping malformed row: ['220', 'Sports courts are untidy and have broken fences', ' creating safety hazards.', 'Sports', '2025-08-29']
# Skipping malformed row: ['221', 'Heating systems in academic blocks are faulty', ' affecting concentration during cold days.', 'Maintenance', '2025-09-04']
# Skipping malformed row: ['222', 'Faculty often do not provide detailed feedback on assignments', ' limiting student improvement.', 'Faculty', '2025-09-08']
# Skipping malformed row: ['226', 'Faculty communication about exam schedules is often delayed', ' causing confusion.', 'Faculty', '2025-08-31']
# Skipping malformed row: ['235', 'Mess food hygiene standards seem to have fallen', ' as reported by multiple students.', 'Hostel', '2025-09-07']
# Skipping malformed row: ['236', 'Sports equipment rooms are often left unlocked', ' raising safety concerns.', 'Sports', '2025-09-01']
# Skipping malformed row: ['242', 'Faculty feedback on practicals lacks clarity', ' which affects lab preparation.', 'Faculty', '2025-09-02']
# Skipping malformed row: ['251', 'The air conditioning in the seminar hall is broken', ' making it unbearable during summer lectures.', 'Maintenance', '2025-09-12']
# Skipping malformed row: ['252', 'Faculty often cancel discussion sessions without informing students in advance', ' disrupting study plans.', 'Faculty', '2025-09-11']
# Skipping malformed row: ['253', 'The cleanliness of the hostel kitchen has significantly declined', ' with pests being spotted frequently.', 'Hostel', '2025-09-10']
# Skipping malformed row: ['254', 'Many of the basketballs used for practice are old and deflated', ' impeding quality training.', 'Sports', '2025-09-09']
# Skipping malformed row: ['255', 'The campus Wi-Fi often drops out during critical lecture presentations', ' frustrating attendees.', 'Maintenance', '2025-09-08']
# Skipping malformed row: ['256', 'Several professors are unresponsive to emails about assignment deadlines', ' causing confusion.', 'Faculty', '2025-09-07']
# Skipping malformed row: ['259', 'The hostel water heater has been out of service for weeks', ' causing severe discomfort.', 'Maintenance', '2025-09-04']
# Skipping malformed row: ['260', 'Faculty fail to update the course portal regularly', ' leaving students without current resources.', 'Faculty', '2025-09-03']
# Skipping malformed row: ['261', 'Unpleasant odors are often present in the east wing of the hostel', ' likely due to poor ventilation.', 'Hostel', '2025-09-02']
# Skipping malformed row: ['262', 'Sports practice schedules are frequently changed with little notice', ' confusing athletes.', 'Sports', '2025-09-01']
# Skipping malformed row: ['263', 'The elevator in the arts building is frequently stuck between floors', ' creating safety hazards.', 'Maintenance', '2025-08-31']
# Skipping malformed row: ['264', 'Several lecturers are unavailable during consultation hours', ' making it difficult to seek help.', 'Faculty', '2025-08-30']
# Skipping malformed row: ['265', 'Mess food has poor variety', ' and frequent repeat menus bore most students.', 'Hostel', '2025-08-29']
# Skipping malformed row: ['266', 'Sports training facilities lack adequate lighting', ' making evening practice difficult.', 'Sports', '2025-08-28']
# Skipping malformed row: ['267', 'Several lights in the hostel corridors have been out for weeks', ' raising safety concerns.', 'Maintenance', '2025-08-27']
# Skipping malformed row: ['270', 'Many sports lockers are broken with faulty locks', ' risking loss of equipment.', 'Sports', '2025-08-24']
# Skipping malformed row: ['271', 'Hot water availability in hostel bathrooms is unreliable', ' especially during mornings.', 'Maintenance', '2025-08-23']
# Skipping malformed row: ['275', 'Fire alarms in several hostel blocks are malfunctioning', ' raising safety issues.', 'Maintenance', '2025-08-19']
# Skipping malformed row: ['276', 'Some faculty members are late to lectures regularly', ' wasting valuable class time.', 'Faculty', '2025-08-18']
# Skipping malformed row: ['279', 'Heating systems in the library are inadequate during cold weather', ' causing discomfort.', 'Maintenance', '2025-08-15']
# Skipping malformed row: ['283', 'Many fans in lecture halls are broken', ' causing discomfort during hot days.', 'Maintenance', '2025-08-11']
# Skipping malformed row: ['287', 'Hostel door locks are faulty causing security concerns', ' especially at night.', 'Maintenance', '2025-08-07']
# Skipping malformed row: ['288', 'Faculty response times for assignment queries are slow', ' causing confusion.', 'Faculty', '2025-08-06']
# Skipping malformed row: ['319', 'Unclean hostel common areas attract pests', ' affecting student comfort.', 'Hostel', '2025-07-06']
# Skipping malformed row: ['323', 'Mess staff behavior is not always courteous', ' making dining experiences unpleasant.', 'Hostel', '2025-07-02']
# Skipping malformed row: ['324', 'Sports trails are narrow and poorly maintained', ' reducing practice effectiveness.', 'Sports', '2025-07-01']
# Skipping malformed row: ['353', 'Mess food hygiene is poor', ' some students have reported getting sick after meals.', 'Hostel', '2025-07-22']
# Skipping malformed row: ['356', 'Faculty rarely hold review sessions before exams', ' leaving students unprepared.', 'Faculty', '2025-07-19']
# Skipping malformed row: ['365', 'Mess food variety is low', ' and repetitive menus reduce student satisfaction.', 'Hostel', '2025-07-10']
# Skipping malformed row: ['367', 'Elevators in hostel block A often break down', ' inconveniencing residents.', 'Maintenance', '2025-07-08']
# Skipping malformed row: ['401', 'Several air conditioning units across campus are malfunctioning', ' causing discomfort during lectures.', 'Maintenance', '2025-06-04']
# Skipping malformed row: ['404', 'The baseball field’s dugouts are in disrepair', ' making them unsafe for players.', 'Sports', '2025-06-01']
# Skipping malformed row: ['407', 'Owing to poor cleaning standards', ' the hostel common rooms are unhygienic.', 'Hostel', '2025-05-29']
# Skipping malformed row: ['410', 'Faculty rarely communicate important exam updates timely', ' causing confusion.', 'Faculty', '2025-05-26']
# Skipping malformed row: ['413', 'Several light bulbs in study lounges have been out for weeks', ' affecting late-hour studies.', 'Maintenance', '2025-05-23']
# Skipping malformed row: ['449', 'Broken windows cause drafts in several hostel rooms', ' negatively impacting health.', 'Maintenance', '2025-04-17']
# Skipping malformed row: ['451', 'Many classroom projectors produce low-quality images', ' affecting presentations.', 'Maintenance', '2025-04-15']
# Skipping malformed row: ['469', 'Hostel common areas are often noisy late into the night', ' disturbing sleep.', 'Hostel', '2025-03-28']
# Skipping malformed row: ['474', 'Sports practice timings clash with other university events', ' causing attendance issues.', 'Sports', '2025-03-23']
# Cleaned CSV saved as: clustering_data_clean.csv

# %%
import os
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv('clustering_data_clean.csv')
df.head()
# Out:
#    id                                     complaint_text     category  \
# 0   1  Room lights malfunction every week and nobody ...  Maintenance
# 1   2                                  Mess food is bad.       Hostel
# 2   3  Lectures are rescheduled last minute without n...      Faculty
# 3   4        Mess staff misbehaves and ignores requests.       Hostel
# 4   6  Professors are rarely available for doubt clea...      Faculty
#
#     timestamp
# 0  2025-08-06
# 1  2025-07-27
# 2  2025-09-02
# 3  2025-07-22
# 4  2025-07-12

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

df['clean_text'] = df['complaint_text'].apply(preprocess)
df.head()
# Out:
#    id                                     complaint_text     category  \
# 0   1  Room lights malfunction every week and nobody ...  Maintenance
# 1   2                                  Mess food is bad.       Hostel
# 2   3  Lectures are rescheduled last minute without n...      Faculty
# 3   4        Mess staff misbehaves and ignores requests.       Hostel
# 4   6  Professors are rarely available for doubt clea...      Faculty
#
#     timestamp                                         clean_text
# 0  2025-08-06   room light malfunction every week nobody attends
# 1  2025-07-27                                      mess food bad
# 2  2025-09-02  lecture rescheduled last minute without notifi...
# 3  2025-07-22              mess staff misbehaves ignores request
# 4  2025-07-12         professor rarely available doubt clearance

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize
    tokens = text.split()
    # Remove stopwords and lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# %%
df['clean_text'] = df['complaint_text'].apply(preprocess)

# Print first 5 rows to check
print(df[['complaint_text', 'clean_text']].head())
# Out:
#                                       complaint_text  \
# 0  Room lights malfunction every week and nobody ...
# 1                                  Mess food is bad.
# 2  Lectures are rescheduled last minute without n...
# 3        Mess staff misbehaves and ignores requests.
# 4  Professors are rarely available for doubt clea...
#
#                                           clean_text
# 0   room light malfunction every week nobody attends
# 1                                      mess food bad
# 2  lecture rescheduled last minute without notifi...
# 3              mess staff misbehaves ignores request
# 4         professor rarely available doubt clearance

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
print(" Model loaded successfully!")
# Out:
#  Model loaded successfully!

# %%
embeddings = model.encode(df['clean_text'].tolist(), convert_to_numpy=True)

os.makedirs('embeddings', exist_ok=True)
np.save('embeddings/embeddings.npy', embeddings)

print(f"✅ Embeddings generated! Shape: {embeddings.shape}")
# Out:
# ✅ Embeddings generated! Shape: (418, 384)

# %%
# Cell 5: Compute Similarity Matrix
from sklearn.metrics.pairwise import cosine_similarity

sim_matrix = cosine_similarity(embeddings)
print(sim_matrix.shape)
# Out:
# (418, 418)

# %%
# Cell 6: Define Custom Similarity + Final Score
def jaccard_similarity(text1, text2):
    """
    Compute Jaccard similarity between two texts based on word overlap.
    """
    set1 = set(text1.split())
    set2 = set(text2.split())
    return len(set1 & set2) / len(set1 | set2)

def final_score(i, j):
    """
    Compute the final similarity score between complaint i and complaint j.
    Combines:
    - Cosine similarity of embeddings
    - Jaccard keyword overlap
    - Category match (if available)
    """
    cosine_sim = sim_matrix[i][j]
    keyword_overlap = jaccard_similarity(df['clean_text'][i], df['clean_text'][j])
    category_match = 1 if df['category'][i] == df['category'][j] else 0
    return (0.7 * cosine_sim) + (0.2 * keyword_overlap) + (0.1 * category_match)

# %%
# Cell 6: Define Dynamic Threshold Function
import numpy as np

def dynamic_threshold(i, base=0.25, scale=0.2):
    """
    Compute a dynamic threshold for each complaint i based on
    the mean and standard deviation of its similarity distribution.
    This makes the threshold adaptive per complaint.
    """
    sims = sim_matrix[i]  # Ensure sim_matrix is already defined
    mean_sim = np.mean(sims)
    std_sim = np.std(sims)
    return base + scale * std_sim + 0.1 * mean_sim  # more context-sensitive threshold

# %%
# Cell 7: Clustering Using Dynamic Threshold
visited = set()
clusters = []

for i in range(len(df)):
    if i in visited:
        continue
    
    current_cluster = [i]
    visited.add(i)
    thr = dynamic_threshold(i)
    
    for j in range(len(df)):
        if j in visited:
            continue
        if final_score(i, j) > thr:
            current_cluster.append(j)
            visited.add(j)
    
    clusters.append(current_cluster)

# Show number of clusters formed
print(f"Clusters formed: {len(clusters)}")
# Out:
# Clusters formed: 23

# %%
#Check Cluster Sizes
cluster_sizes = [len(c) for c in clusters]
print("Number of clusters:", len(clusters))
print("Average cluster size:", sum(cluster_sizes)/len(cluster_sizes))
print("Clusters with size 1:", sum(1 for c in clusters if len(c) == 1))
# Out:
# Number of clusters: 23
# Average cluster size: 18.17391304347826
# Clusters with size 1: 4

# %%
#Calculating confidense score for clusters in detail clustering
import itertools
import numpy as np
def cluster_confidence(cluster, sim_matrix):
    if len(cluster) < 2:
        return 1.0  # single complaint = perfect confidence
    pairwise_sims = [sim_matrix[i][j] for i, j in itertools.combinations(cluster, 2)]
    return np.mean(pairwise_sims)

# Calculate confidence for all clusters
cluster_confidences = [cluster_confidence(c, sim_matrix) for c in clusters]

for i, (c, conf) in enumerate(zip(clusters, cluster_confidences)):
    print(f"Cluster {i+1} | Size: {len(c)} | Confidence: {conf:.2f}")
# Out:
# Cluster 1 | Size: 64 | Confidence: 0.39
# Cluster 2 | Size: 70 | Confidence: 0.46
# Cluster 3 | Size: 79 | Confidence: 0.42
# Cluster 4 | Size: 31 | Confidence: 0.46
# Cluster 5 | Size: 46 | Confidence: 0.43
# Cluster 6 | Size: 35 | Confidence: 0.41
# Cluster 7 | Size: 31 | Confidence: 0.52
# Cluster 8 | Size: 2 | Confidence: 0.36
# Cluster 9 | Size: 18 | Confidence: 0.66
# Cluster 10 | Size: 6 | Confidence: 0.44
# Cluster 11 | Size: 4 | Confidence: 0.38
# Cluster 12 | Size: 6 | Confidence: 1.00
# Cluster 13 | Size: 3 | Confidence: 0.33
# Cluster 14 | Size: 3 | Confidence: 0.35
# Cluster 15 | Size: 6 | Confidence: 0.34
# Cluster 16 | Size: 3 | Confidence: 0.40
# Cluster 17 | Size: 2 | Confidence: 0.31
# Cluster 18 | Size: 1 | Confidence: 1.00
# Cluster 19 | Size: 3 | Confidence: 0.25
# Cluster 20 | Size: 1 | Confidence: 1.00
# Cluster 21 | Size: 1 | Confidence: 1.00
# Cluster 22 | Size: 2 | Confidence: 0.49
# Cluster 23 | Size: 1 | Confidence: 1.00

# %%
def representative_complaint(cluster, df):
    # Option 1: Pick the longest complaint
    return max(cluster, key=lambda idx: len(df['complaint_text'][idx]))

# Example: pick representative for first cluster
rep_idx = representative_complaint(clusters[0], df)
print("Representative Complaint:", df['complaint_text'][rep_idx])
# Out:
# Representative Complaint: The classroom fans are broken and have not been fixed. Several maintenance requests were filed with no resolution. The issue has inconvenienced students for weeks and some have missed assessments as a direct result.

# %%
for i, cluster in enumerate(clusters, start=1):
    print(f"\n🔹 Cluster {i} | Size: {len(cluster)} | Confidence: {cluster_confidences[i-1]:.2f}")
    for idx in cluster:
        print(f"   - {df['complaint_text'][idx]} ({df['category'][idx]})")
# Out:
# 🔹 Cluster 1 | Size: 64 | Confidence: 0.39
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - The classroom fans are broken and have not been fixed. Several maintenance requests were filed with no resolution. The issue has inconvenienced students for weeks and some have missed assessments as a direct result. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Room lights malfunction every week and nobody attends. (Maintenance)
#    - Water pressure in the hostel bathrooms drops drastically in the evening hours. (Maintenance)
#    - Heating system in the hostel rooms is unreliable leading to cold nights for residents. (Maintenance)
#    - Hostel lights frequently go off at night causing safety concerns. (Hostel)
#    - Repeated complaints about noisy air conditioners in study halls have had no response. (Maintenance)
#    - Broken taps in hostel bathrooms cause water wastage and inconvenience. (Maintenance)
#    - Delayed repairs to damaged hostel furniture causing discomfort. (Maintenance)
#    - Water heater in hostel bathrooms often malfunctions during winter. (Maintenance)
#    - The heating in hostel block A rooms is completely unreliable at night; many students struggle to sleep. (Maintenance)
#    - Electrical socket issues in study rooms cause disruptions during computer labs. (Maintenance)
#    - Flickering lights in hostel study areas make it hard to focus during late study hours. (Maintenance)
#    - Several hostels suffer from irregular garbage collection leading to smells and pests. (Maintenance)
#    - Hostel common rooms frequently unavailable due to poor maintenance and scheduling issues. (Hostel)
#    - Air conditioning units in library often malfunction during peak usage times. (Maintenance)
#    - Several toilets in the hostel are broken and have not been repaired for weeks. (Maintenance)
#    - Heating system malfunctions in study halls leading to discomfort amidst exams. (Maintenance)
#    - Recurring power outages disrupt hostel activities and cause safety concerns. (Maintenance)
#    - Several floors in the hostel suffer from poor elevator service disrupting mobility. (Maintenance)
#    - Heating malfunctions in student lounges cause discomfort during late night group studies. (Maintenance)
#    - Water leakage issues in hostel rooms cause property damage and inconvenience. (Maintenance)
#    - The seminar hall projector has been malfunctioning for weeks causing disruption in classes. (Maintenance)
#    - Sports ground floodlights are dim and often don’t turn on during evening matches. (Sports)
#    - Several electrical outlets in the hostel common rooms are non-functional for months. (Maintenance)
#    - Water leakage from AC units in academic buildings causing damage to furniture. (Maintenance)
#    - Poor ventilation in hostel rooms causes discomfort during hot weather. (Maintenance)
#    - Frequent power fluctuations disrupt hostel study environments. (Maintenance)
#    - Faulty heating systems in library cause disturbances during winter sessions. (Maintenance)
#    - Water supply interruptions in hostel block cause major inconvenience. (Maintenance)
#    - Broken lights in sports locker rooms create unsafe conditions. (Sports)
#    - Intermittent water supply problems in hostel causing hygiene concerns. (Maintenance)
#    - Heating malfunctions in hostel at night leaving students uncomfortable. (Maintenance)
#    - Lack of sufficient lights in hostel outdoor areas causing safety concerns. (Maintenance)
#    - Recurring electrical faults in student housing disrupt daily routines. (Maintenance)
#    - Hostel laundry machines frequently out of order increasing wait times. (Maintenance)
#    - Lighting in the student common area is dim and often flickers causing discomfort. (Maintenance)
#    - Air conditioning in common study rooms is either too cold or not working at all. (Maintenance)
#    - Frequent power cuts in hostels cause interruptions in study routines. (Maintenance)
#    - Air quality in study halls is poor due to lack of ventilation. (Maintenance)
#    - Broken lights in hallways create unsafe conditions especially at night. (Maintenance)
#    - Water pressure in several hostel blocks is inconsistent leading to frequent outages. (Maintenance)
#    - Elevator malfunctions in academic blocks create problems especially for disabled students. (Maintenance)
#    - Frequent power outages in hostels disrupt exam preparation and sleep schedules. (Maintenance)
#    - Recurrent plumbing issues in hostel bathrooms cause water wastage and discomfort. (Maintenance)
#    - Study hall air conditioning systems need urgent maintenance with several failures. (Maintenance)
#    - Heating radiators in some hostel rooms are broken leading to cold conditions at night. (Maintenance)
#    - Several hostel water taps leak continuously wasting water and increasing bills. (Maintenance)
#    - Broken light switches in hallways cause frequent outages in student study areas. (Maintenance)
#    - Water supply interruptions in hostel cause major inconveniences during exams. (Maintenance)
#    - Air conditioners in study rooms malfunction regularly disrupting focus. (Maintenance)
#    - Faulty heaters in hostels make it difficult to concentrate during cold nights. (Maintenance)
#    - Lighting in the computer lab is dim making long study sessions tiring. (Maintenance)
#    - Broken windows in hostel rooms let in cold wind and noise disrupting sleep. (Maintenance)
#    - Heating system malfunctions in hostels make winters extremely uncomfortable. (Maintenance)
#    - Power outages in the hostel cause disruptions during evening study hours. (Maintenance)
#
# 🔹 Cluster 2 | Size: 70 | Confidence: 0.46
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. Several maintenance requests were filed with no resolution. The issue has inconvenienced students for weeks and some have missed assessments as a direct result. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess food is bad. Several maintenance requests were filed with no resolution. The issue has inconvenienced students for weeks and some have missed assessments as a direct result. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. Several maintenance requests were filed with no resolution. The issue has inconvenienced students for weeks and some have missed assessments as a direct result. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess staff misbehaves and ignores requests. (Hostel)
#    - Mess food is bad. (Hostel)
#    - Mess food portions are reduced without informing residents; many complain about constant hunger. (Hostel)
#    - Mess utensils are often unclean leading to worries about food contamination. (Hostel)
#    - Mess food preparation areas are frequently untidy raising hygiene questions. (Hostel)
#    - Mess staff often serve cold food despite high temperatures leading to food safety worries. (Hostel)
#    - Poor recycling and trash disposal facilities in the hostel increase pest problems. (Hostel)
#    - Mess food portions are too small and do not satisfy nutritional needs of active students. (Hostel)
#    - Multiple complaints of unhygienic mess utensils leading to student health concerns. (Hostel)
#    - Mess meals are sometimes served cold despite complaints from residents. (Hostel)
#    - Mess staff behavior has worsened; complaints about rudeness are common among residents. (Hostel)
#    - The mess staff often serve cold parcels for students attending early classes. (Hostel)
#    - Mess utensils often appear unclean leading to health concerns among residents. (Hostel)
#    - Mess food portions are small and leave many students hungry after meals. (Hostel)
#    - The mess area garbage bins overflow frequently causing foul odor. (Hostel)
#    - Mess staff hygiene practices are questionable impacting food safety. (Hostel)
#    - Frequent delays in mess meal timings have caused inconvenience during tight schedules. (Hostel)
#    - Hostel food quality fluctuates greatly between meals often leading to complaints. (Hostel)
#    - Mess staff sometimes neglect hygiene standards compromising food safety. (Hostel)
#    - Mess menus lack nutritional balance impacting student health during exam periods. (Hostel)
#    - Mess facilities lack sufficient seating causing overcrowding during peak hours. (Hostel)
#    - Mess food served cold frequently despite complaints from students. (Hostel)
#    - Mess food portions are inconsistent and sometimes insufficient. (Hostel)
#    - Mess dining area often overcrowded and uncomfortable during meal times. (Hostel)
#    - Mess staff attitude is sometimes rude which negatively affects dining atmosphere. (Hostel)
#    - Mess kitchen often smells bad due to poor ventilation. (Hostel)
#    - Mess portion sizes sometimes do not meet student nutritional needs. (Hostel)
#    - Mess utensils are often unclean leading to concern among students. (Hostel)
#    - Mess dining area cleanliness has declined over the semester. (Hostel)
#    - Mess staff hygiene practices often do not meet expected standards. (Hostel)
#    - Mess food quality fluctuates making dining experience unpredictable. (Hostel)
#    - Unpleasant odors in hostel corridors due to sanitation issues. (Hostel)
#    - The hostel mess has had multiple hygiene violations leading to student health concerns. (Hostel)
#    - Pest infestations have worsened in the hostel dormitories due to poor sanitation. (Hostel)
#    - Mess food portions often do not meet the caloric requirements of active students. (Hostel)
#    - Dining area cleanliness fluctuates with occasional presence of pests causing concern. (Hostel)
#    - Mess food consistency varies leading to unpredictable meal quality affecting students. (Hostel)
#    - Inadequate sanitation staff leads to unclean hostels especially during weekends. (Hostel)
#    - Mess food sometimes spoiled due to storage issues causing health concerns. (Hostel)
#    - Mess utensils are sometimes old or cracked which may cause health hazards. (Hostel)
#    - Unhygienic conditions in the mess area have worsened during hotter months. (Hostel)
#    - Mess food sometimes smells bad and causes students to avoid meals. (Hostel)
#    - Mess food quality dips drastically during exam weeks causing dissatisfaction. (Hostel)
#    - Mess waste is not cleared regularly leading to pest issues near dining halls. (Hostel)
#
# 🔹 Cluster 3 | Size: 79 | Confidence: 0.42
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Delay in releasing project grades is affecting internships. (Faculty)
#    - Lectures are rescheduled last minute without notifications. (Faculty)
#    - Faculty delayed releasing exam results which is hampering my scholarship application process. (Faculty)
#    - Faculty delays in updating course materials online impact study schedules. (Faculty)
#    - Some faculty members are not accessible outside class hours for clarifications. (Faculty)
#    - Delayed responses from faculty regarding internship approvals affecting student plans. (Faculty)
#    - Faculty often postpone scheduled classes citing administrative work load. (Faculty)
#    - Faculty seminars and extra help sessions are rarely arranged for difficult subjects. (Faculty)
#    - Faculty communication about changes in course structure is inadequate. (Faculty)
#    - Faculty office hours clash with lecture timings making it hard to meet instructors. (Faculty)
#    - Our faculty sometimes miss scheduled office hours without notifying students in advance. (Faculty)
#    - Delay in updating coursework material online is causing confusion and falling behind. (Faculty)
#    - Faculty communication channels are often unresponsive causing delay in solving queries. (Faculty)
#    - Lack of timely response from faculty about grade appeals causing student anxiety. (Faculty)
#    - Course instructors often reschedule classes last minute without informing students. (Faculty)
#    - Faculty are sometimes hard to reach for clarifications outside class hours. (Faculty)
#    - Faculty occasionally fail to respond to emails about project deadlines and requirements. (Faculty)
#    - Lack of detailed syllabus updates from faculty creates confusion among students. (Faculty)
#    - Faculty availability for extra help sessions is inconsistent causing frustration. (Faculty)
#    - Some course materials are not uploaded online despite deadlines approaching. (Faculty)
#    - Lack of timely feedback from faculty on term papers affects study planning. (Faculty)
#    - Faculty members sometimes do not hold scheduled revision classes. (Faculty)
#    - Delay in faculty posting lecture notes online affects exam preparations. (Faculty)
#    - Faculty members frequently delay in uploading course materials which affects learning. (Faculty)
#    - Unexpected cancellation of tutorials by faculty without prior notification. (Faculty)
#    - Faculty members are often late or miss scheduled office hours. (Faculty)
#    - Difficulty in communication with faculty regarding course changes. (Faculty)
#    - Faculty are often unavailable during consultation appointments. (Faculty)
#    - Faculty delay grading assignments impacting student planning. (Faculty)
#    - Faculty information about exam schedules is not distributed systematically. (Faculty)
#    - Faculty are sometimes late starting lectures affecting syllabus coverage. (Faculty)
#    - Faculty members are frequently late to classes which disrupts the learning schedule. (Faculty)
#    - Faculty are not accessible outside of class hours for additional academic help. (Faculty)
#    - Faculty responses to student queries on assignments are often delayed. (Faculty)
#    - Faculty sometimes cancel lectures unexpectedly which disrupts learning pace. (Faculty)
#    - Faculty lecture slides are often outdated or missing important information. (Faculty)
#    - Lack of timely communication from faculty regarding syllabus changes. (Faculty)
#    - Faculty communication channels are often unresponsive during critical times. (Faculty)
#    - Faculty can be difficult to reach for course advice outside class hours. (Faculty)
#    - Faculty frequently reschedule office hours without notifying students affecting accessibility. (Faculty)
#    - Lecturers sometimes skip critical portions of the syllabus without explanation. (Faculty)
#    - Lecturers seldom hold extra help sessions for difficult subjects impacting grades. (Faculty)
#    - Sporadic faculty availability limits student access to guidance outside lecture hours. (Faculty)
#    - Faculty sometimes delay in releasing end-of-year results causing anxiety among students. (Faculty)
#    - Some sports practices are cancelled last minute without notification impacting preparedness. (Sports)
#    - Faculty office hours clash with other mandatory events reducing student access. (Faculty)
#    - Faculty often revise exam formats late causing students to scramble last minute. (Faculty)
#    - Faculty members sometimes do not post lecture notes on time affecting revision. (Faculty)
#    - Professors delay grading making it hard to plan for remedial classes. (Faculty)
#    - Faculty sometimes cancel revision sessions days before exams without prior notice. (Faculty)
#    - Faculty sometimes rearrange class schedules at short notice causing confusion. (Faculty)
#    - Mess serving times sometimes do not align with lecture schedules. (Hostel)
#    - Faculty availability for consultation fluctuates across semesters. (Faculty)
#    - Timely and clear faculty communication is often lacking for assessments. (Faculty)
#    - Faculty sometimes provide inconsistent information across lecture groups. (Faculty)
#    - Faculty occasionally reschedule exams which affect student preparation. (Faculty)
#
# 🔹 Cluster 4 | Size: 31 | Confidence: 0.46
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Professors are rarely available for doubt clearance. (Faculty)
#    - Lack of clarity from faculty regarding project deadlines is causing confusion. (Faculty)
#    - Lack of detailed exam review sessions from faculty frustrating students. (Faculty)
#    - Unclear guidelines from faculty on grading criteria are confusing students. (Faculty)
#    - Faculty grading criteria are sometimes unclear and inconsistently applied. (Faculty)
#    - Professors sometimes give ambiguous instructions about assignment submissions. (Faculty)
#    - Some faculty provide minimal clarification on complex topics leaving students confused. (Faculty)
#    - Faculty provide insufficient guidance on lab practicals leading to poor understanding. (Faculty)
#    - Inconsistent faculty feedback makes exam preparation difficult. (Faculty)
#    - Faculty do not provide adequate exam preparation materials and support. (Faculty)
#    - Faculty communication is sometimes vague causing confusion in coursework. (Faculty)
#    - Faculty often do not provide detailed marking criteria for assignments causing confusion. (Faculty)
#    - Faculty sometimes fail to provide clear guidelines on projects and exams. (Faculty)
#    - Faculty availability is limited during exam preparation affecting performance. (Faculty)
#    - Faculty sometimes provide vague grading rubrics leading to misunderstandings. (Faculty)
#    - Faculty are often unreachable during crucial weeks before exams leading to poor prep. (Faculty)
#    - Faculty communication about course prerequisites misses vital information. (Faculty)
#    - Lack of detailed faculty feedback on subjective papers causes confusion. (Faculty)
#    - Faculty rarely communicate proper grading policies affecting student trust. (Faculty)
#    - Faculty often provide insufficient details in assignment instructions causing confusion. (Faculty)
#    - Faculty often fail to provide feedback on assignments in a timely manner. (Faculty)
#    - Faculty do not always clarify grading criteria leading to uncertainty. (Faculty)
#    - Faculty often do not conduct promised extra tutorials before exams. (Faculty)
#
# 🔹 Cluster 5 | Size: 46 | Confidence: 0.43
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Rodded chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Broken chairs in the gym are unsafe for use. (Sports)
#    - Several broken benches near the sports ground have not been repaired for months. (Sports)
#    - Sports tracks have uneven surfaces causing risk of injury during practice. (Sports)
#    - Some sports training equipment is outdated and unsafe to use. (Sports)
#    - The sports complex lacks first aid facilities for injured athletes. (Sports)
#    - Sports facilities maintenance staff are unresponsive to repair requests. (Sports)
#    - The sports gym has broken treadmills and no replacement has been scheduled yet. (Sports)
#    - Some gym equipment is outdated and causes minor injuries during workouts. (Sports)
#    - Some sports facilities are closed unexpectedly without notice affecting practice. (Sports)
#    - The outdoor volleyball court has many cracks leading to unsafe playing conditions. (Sports)
#    - Some gym machines at the sports complex are out of order for weeks. (Sports)
#    - Unsatisfactory maintenance of outdoor sports fields reduces usable practice area. (Sports)
#    - The outdoor basketball court surface is eroded and unsafe for play. (Sports)
#    - Broken gym equipment remains unrepaired for weeks creating hazards. (Sports)
#    - Lack of access to sports equipment due to poor maintenance. (Sports)
#    - The athletic track has several cracks and needs urgent resurfacing. (Sports)
#    - Some sports equipment is outdated and not safe for regular use. (Sports)
#    - Sports facilities are often locked without notice preventing practice. (Sports)
#    - Broken fencing around soccer field makes it difficult to manage games. (Sports)
#    - Some gym equipment does not have proper instructions causing misuse. (Sports)
#    - Several sports nets around the basketball court are torn and need urgent replacement. (Sports)
#    - The tennis courts have broken surfaces making them unsafe for play. (Sports)
#    - Broken equipment in the gym has not been fixed for several weeks. (Sports)
#    - Some gym machines have safety issues which have not been addressed. (Sports)
#    - Sports courts are inadequately maintained leading to injuries. (Sports)
#    - Broken seats and equipment in the sports gym have not been repaired. (Sports)
#    - Some sports facilities are unavailable due to poor maintenance. (Sports)
#    - Cracks and uneven surfaces on the running track cause frequent injuries. (Sports)
#    - Lack of first-aid kits at sports events jeopardizes student safety. (Sports)
#    - Broken safety nets on volleyball courts impact practice session quality. (Sports)
#    - The soccer field’s goalposts are unstable posing safety risks during games. (Sports)
#    - Missing or damaged weights in weight training room hinder fitness routines. (Sports)
#    - Uneven surfaces on the basketball court have led to many student injuries. (Sports)
#    - Sports equipment is old and frequently breaking down during practice. (Sports)
#    - Several sports courts have broken fencing causing safety hazards. (Sports)
#    - Old sports equipment leads to frequent injuries during practice sessions. (Sports)
#    - The track and field area requires urgent maintenance to be safe for use. (Sports)
#    - Some sports facilities are closed unexpectedly without informing students. (Sports)
#
# 🔹 Cluster 6 | Size: 35 | Confidence: 0.41
#    - No water facility in sports complex. (Sports)
#    - Football field needs maintenance. (Sports)
#    - Football field needs maintenance. (Sports)
#    - No water facility in sports complex. (Sports)
#    - Football field needs maintenance. (Sports)
#    - No water facility in sports complex. (Sports)
#    - Football field needs maintenance. (Sports)
#    - No water facility in sports complex. (Sports)
#    - Football field needs maintenance. (Sports)
#    - No water facility in sports complex. (Sports)
#    - Football field needs maintenance. (Sports)
#    - No water facility in sports complex. (Sports)
#    - Football field needs maintenance. (Sports)
#    - Football field needs maintenance. (Sports)
#    - Football field needs maintenance. (Sports)
#    - Football field needs maintenance. (Sports)
#    - Sports facilities booking system is faulty leading to scheduling conflicts. (Sports)
#    - The sports ground parking lot is too small leading to congestion during events. (Sports)
#    - Some sports fields are inaccessible due to poor drainage during rainy days. (Sports)
#    - Several often-used sports fields are waterlogged and inaccessible due to poor drainage. (Sports)
#    - Sports equipment booking system is confusing and often results in double bookings. (Sports)
#    - Lack of water stations near sports fields causes dehydration risks during summer. (Sports)
#    - Limited access to indoor sports facilities on weekends creates scheduling problems. (Sports)
#    - Sports equipment like rackets and balls are old and need immediate replacement. (Sports)
#    - Water supply interruptions during sports practice sessions affect hydration. (Sports)
#    - The tennis court nets are torn and have not been replaced for a long time. (Sports)
#    - Sports field drainage is poor resulting in waterlogging after rains. (Sports)
#    - Water leaks on sports fields affect usability during rainy seasons. (Sports)
#    - Sports schedules are not coordinated leading to overlaps and confusion. (Sports)
#    - Several sports event cancellations due to poor ground conditions unfairly affect teams. (Sports)
#    - Many sports nets (badminton/tennis) have holes reducing training quality. (Sports)
#    - Insufficient lighting in outdoor sports facilities reduces evening practice opportunities. (Sports)
#    - The sports complex locker rooms lack adequate ventilation and are often damp. (Sports)
#    - Lack of professional coaching for indoor sports is hampering skill development. (Sports)
#    - Several sports fields lack proper drainage leading to cancellations during rains. (Sports)
#
# 🔹 Cluster 7 | Size: 31 | Confidence: 0.52
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - Internet not working in hostel rooms for days. (Hostel)
#    - The hostel Wi-Fi signal is extremely weak on the upper floors making communication difficult. (Hostel)
#    - Hostel recreational areas are frequently dirty and not maintained properly. (Hostel)
#    - Hostel corridors often left unlocked compromising student security. (Hostel)
#    - Hostel lacks adequate garbage disposal system causing unpleasant odors. (Hostel)
#    - Frequent water shortages in hostel blocks affect daily routines significantly. (Hostel)
#    - Hostel recreation areas need urgent maintenance due to frequent damages. (Hostel)
#    - Inconsistent cleaning schedules of hostel bathrooms lowering hygiene standards. (Hostel)
#    - Dirty hostel bathrooms reduce student morale and comfort. (Hostel)
#    - Significant delays in water supply in hostels make daily hygiene challenging. (Hostel)
#    - Unclean conditions reported around hostel waste disposal areas. (Hostel)
#    - New hostel residents face difficulty adjusting due to insufficient orientation on facilities. (Hostel)
#    - Hostel Wi-Fi drops frequently causing issues for students attending online lectures. (Hostel)
#    - The hostel common room Wi-Fi is extremely slow limiting group study sessions. (Hostel)
#    - Lack of proper cleaning in hostel bathrooms results in unhygienic conditions. (Hostel)
#    - Hostel Wi-Fi often disconnects causing interruptions to study and research. (Hostel)
#    - Student common areas in hostels lack proper ventilation. (Hostel)
#    - Hostel laundry machines break down often causing long waiting times. (Hostel)
#    - Dining areas in hostels are often overcrowded and noisy. (Hostel)
#
# 🔹 Cluster 8 | Size: 2 | Confidence: 0.36
#    - There are electrical short circuits in the study hall. (Maintenance)
#    - Electrical wiring issues cause power loss during important lectures. (Maintenance)
#
# 🔹 Cluster 9 | Size: 18 | Confidence: 0.66
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Coaches do not attend practice on time. (Sports)
#    - Some sports coaches fail to provide consistent training sessions as scheduled. (Sports)
#    - Lack of qualified sports coaching staff has reduced training quality significantly. (Sports)
#    - Frequent cancellations of sports practice sessions without prior notice. (Sports)
#    - Some sports training schedules frequently get changed at short notice. (Sports)
#    - Lack of certified coaches reduces effectiveness of sports training programs. (Sports)
#    - Frequent cancellation of sports training sessions without notice frustrates students. (Sports)
#    - Lack of qualified coaches affects the quality of sports training. (Sports)
#
# 🔹 Cluster 10 | Size: 6 | Confidence: 0.44
#    - Faculty feedback is not constructive. (Faculty)
#    - Staff do not respond to emails about course selection. (Faculty)
#    - Staff do not respond to emails about course selection. (Faculty)
#    - Faculty provide minimal feedback on essay submissions which limits student progress. (Faculty)
#    - Faculty do not provide clear marking rubrics for assessments. (Faculty)
#    - Faculty feedback on essays is inconsistent across different instructors. (Faculty)
#
# 🔹 Cluster 11 | Size: 4 | Confidence: 0.38
#    - UPVC windows are leaking during heavy rains. (Maintenance)
#    - Leaking roofs in academic blocks cause distractions and damage personal belongings. (Maintenance)
#    - Broken windows and poor sealing in hostel rooms cause drafts. (Maintenance)
#    - Water leaks in academic buildings lead to occasional class disruptions. (Maintenance)
#
# 🔹 Cluster 12 | Size: 6 | Confidence: 1.00
#    - The classroom fans are broken and have not been fixed. (Maintenance)
#    - The classroom fans are broken and have not been fixed. (Maintenance)
#    - The classroom fans are broken and have not been fixed. (Maintenance)
#    - The classroom fans are broken and have not been fixed. (Maintenance)
#    - The classroom fans are broken and have not been fixed. (Maintenance)
#    - The classroom fans are broken and have not been fixed. (Maintenance)
#
# 🔹 Cluster 13 | Size: 3 | Confidence: 0.33
#    - Frequent power outages affect online classes; no timely updates or solutions from maintenance. (Maintenance)
#    - Maintenance requests take weeks to get resolved leading to dissatisfaction. (Maintenance)
#    - The backup generator in hostels does not work leading to power disruptions. (Maintenance)
#
# 🔹 Cluster 14 | Size: 3 | Confidence: 0.35
#    - Repeated complaints about the leaking roof near the basketball court have been ignored. (Sports)
#    - Some sports events are poorly scheduled leading to conflicts and cancellations. (Sports)
#    - Basketball nets are often tattered and not replaced promptly. (Sports)
#
# 🔹 Cluster 15 | Size: 6 | Confidence: 0.34
#    - Elevator in the main academic block often breaks down causing inconvenience. (Maintenance)
#    - Damage to hostel study room furniture affecting student health and posture. (Maintenance)
#    - Heating in academic blocks is unreliable resulting in discomfort during cold days. (Maintenance)
#    - Hot water pipes in hostels burst frequently causing inconvenience. (Maintenance)
#    - Heating in the library is inconsistent leading to student discomfort during exams. (Maintenance)
#    - Several lockers in hostel common areas have broken locks posing security risks. (Maintenance)
#
# 🔹 Cluster 16 | Size: 3 | Confidence: 0.40
#    - Leaky taps and faucets in hostel washrooms cause water wastage and discomfort. (Maintenance)
#    - Unpleasant smell in the basement common room due to stagnant water. (Hostel)
#    - Lack of hot water in hostel bathrooms during winters affects comfort. (Maintenance)
#
# 🔹 Cluster 17 | Size: 2 | Confidence: 0.31
#    - The jogging track surface is uneven and causes injuries to runners frequently. (Sports)
#    - Broken nets on the cricket pitch reduce the quality of training sessions. (Sports)
#
# 🔹 Cluster 18 | Size: 1 | Confidence: 1.00
#    - Incomplete sports gear inventory makes it difficult to conduct official matches. (Sports)
#
# 🔹 Cluster 19 | Size: 3 | Confidence: 0.25
#    - Unhygienic conditions in the laundry area due to delayed cleaning routines. (Hostel)
#    - Unpleasant odors in the hostel basement due to drainage issues. (Hostel)
#    - Mess staff are often inattentive leading to long waiting times during peak hours. (Hostel)
#
# 🔹 Cluster 20 | Size: 1 | Confidence: 1.00
#    - Delay in posting grades for midterms has created anxiety among students. (Faculty)
#
# 🔹 Cluster 21 | Size: 1 | Confidence: 1.00
#    - The auditorium sound system is outdated causing poor audio quality during events. (Maintenance)
#
# 🔹 Cluster 22 | Size: 2 | Confidence: 0.49
#    - Heating systems in the library are insufficient during winter creating an uncomfortable environment. (Maintenance)
#    - Heating in the computer lab is faulty causing discomfort to long study sessions. (Maintenance)
#
# 🔹 Cluster 23 | Size: 1 | Confidence: 1.00
#    - Noise pollution from construction nearby disrupts classes and studies regularly. (Maintenance)

# %%
cluster_texts = []

for c in clusters:
    # Join all complaints in the cluster into one string
    cluster_text = " ".join(df['complaint_text'][i] for i in c)
    cluster_texts.append(cluster_text)

# %%
cluster_summaries = []

for text in cluster_texts:
    # Split by period
    sentences = text.split('.')
    # Take first 2–3 sentences for short summary
    short_summary = '. '.join(sentences[:3]).strip()
    cluster_summaries.append(short_summary)

# %%
import yake

kw_extractor = yake.KeywordExtractor(top=5, stopwords=None)

final_cluster_summaries = []

for idx, text in enumerate(cluster_texts):
    sentences = text.split('.')
    short_summary = '. '.join(sentences[:3]).strip()
    
    # Extract keywords from cleaned text
    cluster_clean_text = " ".join(df['clean_text'][i] for i in clusters[idx])
    keywords = [kw for kw, score in kw_extractor.extract_keywords(cluster_clean_text)]
    
    final_summary = f"{short_summary} | Keywords: {', '.join(keywords)}"
    final_cluster_summaries.append(final_summary)

# %%
print(f"Number of clusters: {len(clusters)}")
print(f"First 5 clusters: {clusters[:5]}")
# Out:
# Number of clusters: 23
# First 5 clusters: [[0, 17, 26, 44, 53, 65, 79, 89, 99, 116, 125, 138, 145, 151, 153, 157, 164, 168, 170, 177, 185, 188, 190, 192, 194, 198, 201, 224, 228, 232, 234, 237, 238, 242, 246, 250, 253, 255, 258, 263, 267, 271, 275, 279, 284, 291, 297, 313, 321, 329, 332, 342, 346, 350, 358, 362, 374, 386, 389, 392, 400, 404, 412, 416], [1, 3, 11, 15, 20, 27, 30, 35, 40, 43, 50, 54, 60, 63, 69, 72, 80, 82, 88, 94, 98, 103, 107, 110, 115, 121, 123, 128, 134, 155, 162, 179, 182, 183, 186, 199, 207, 212, 214, 220, 222, 230, 236, 240, 244, 248, 257, 261, 273, 277, 289, 299, 303, 307, 311, 315, 319, 323, 328, 333, 336, 340, 348, 352, 360, 364, 368, 376, 391, 394], [2, 7, 18, 22, 32, 36, 41, 45, 49, 55, 59, 66, 70, 75, 81, 87, 90, 93, 100, 106, 109, 118, 120, 129, 132, 133, 140, 146, 147, 154, 161, 165, 169, 171, 173, 175, 178, 181, 189, 193, 195, 202, 219, 225, 229, 233, 235, 243, 247, 256, 260, 264, 268, 272, 282, 292, 294, 298, 306, 314, 318, 326, 327, 330, 339, 347, 351, 357, 363, 367, 375, 379, 387, 397, 402, 405, 409, 413, 417], [4, 24, 38, 51, 62, 78, 97, 113, 126, 142, 150, 158, 206, 216, 239, 251, 254, 276, 280, 288, 302, 310, 335, 343, 355, 359, 370, 371, 383, 390, 401], [5, 25, 39, 42, 52, 68, 95, 108, 124, 135, 144, 152, 156, 167, 172, 184, 204, 208, 227, 231, 241, 245, 252, 262, 266, 270, 274, 278, 283, 286, 290, 300, 304, 312, 320, 331, 334, 337, 345, 349, 377, 385, 388, 407, 411, 415]]

# %%
print(df.head())
print(df.columns)
# Out:
#    id                                     complaint_text     category  \
# 0   1  Room lights malfunction every week and nobody ...  Maintenance
# 1   2                                  Mess food is bad.       Hostel
# 2   3  Lectures are rescheduled last minute without n...      Faculty
# 3   4        Mess staff misbehaves and ignores requests.       Hostel
# 4   6  Professors are rarely available for doubt clea...      Faculty
#
#     timestamp                                         clean_text
# 0  2025-08-06   room light malfunction every week nobody attends
# 1  2025-07-27                                      mess food bad
# 2  2025-09-02  lecture rescheduled last minute without notifi...
# 3  2025-07-22              mess staff misbehaves ignores request
# 4  2025-07-12         professor rarely available doubt clearance
# Index(['id', 'complaint_text', 'category', 'timestamp', 'clean_text'], dtype='object')

# %%
import string
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    text = text.lower().translate(str.maketrans('', '', string.punctuation))
    tokens = [lemmatizer.lemmatize(w) for w in text.split() if w not in stop_words]
    return ' '.join(tokens)

df['clean_text'] = df['complaint_text'].apply(preprocess)

# %%
import yake

kw_extractor = yake.KeywordExtractor(top=5, stopwords=None)

final_cluster_summaries = []

for idx, c in enumerate(clusters):
    if not c:
        final_cluster_summaries.append("Empty cluster")
        continue
    
    # Combine all complaints
    cluster_text = " ".join(df['complaint_text'][i] for i in c)
    
    # Take first 2 sentences (simple split)
    sentences = cluster_text.split('.')
    short_summary = '. '.join(sentences[:2]).strip()
    
    # Keywords from cleaned text
    cluster_clean_text = " ".join(df['clean_text'][i] for i in c)
    keywords = [kw for kw, score in kw_extractor.extract_keywords(cluster_clean_text)]
    
    summary = f"{short_summary} | Keywords: {', '.join(keywords)}"
    final_cluster_summaries.append(summary)
for i, s in enumerate(final_cluster_summaries):
    print(f"Cluster {i} summary: {s}\n")
# Out:
# Cluster 0 summary: Room lights malfunction every week and nobody attends.  The classroom fans are broken and have not been fixed | Keywords: room light malfunction, attends room light, heating system malfunction, hostel common room, study room malfunction
#
# Cluster 1 summary: Mess food is bad.  Mess staff misbehaves and ignores requests | Keywords: mess food bad, food bad mess, request mess food, bad mess staff, mess staff misbehaves
#
# Cluster 2 summary: Lectures are rescheduled last minute without notifications.  Delay in releasing project grades is affecting internships | Keywords: releasing project grade, delay releasing project, project grade affecting, grade affecting internship, notification delay releasing
#
# Cluster 3 summary: Professors are rarely available for doubt clearance.  Professors are rarely available for doubt clearance | Keywords: doubt clearance professor, clearance professor rarely, doubt clearance lack, doubt clearance, professor rarely
#
# Cluster 4 summary: Broken chairs in the gym are unsafe for use.  Broken chairs in the gym are unsafe for use | Keywords: chair gym unsafe, broken chair gym, unsafe play broken, facility closed unexpectedly, rodded chair gym
#
# Cluster 5 summary: No water facility in sports complex.  Football field needs maintenance | Keywords: complex football field, maintenance football field, sport complex football, maintenance water facility, facility sport complex
#
# Cluster 6 summary: Internet not working in hostel rooms for days.  Internet not working in hostel rooms for days | Keywords: day internet working, room day internet, internet working hostel, working hostel room, hostel room day
#
# Cluster 7 summary: There are electrical short circuits in the study hall.  Electrical wiring issues cause power loss during important lectures | Keywords: loss important lecture, short circuit study, circuit study hall, power loss important, electrical short circuit
#
# Cluster 8 summary: Coaches do not attend practice on time.  Coaches do not attend practice on time | Keywords: attend practice time, coach attend practice, time coach attend, practice time coach, attend practice
#
# Cluster 9 summary: Faculty feedback is not constructive.  Staff do not respond to emails about course selection | Keywords: staff respond email, constructive staff respond, selection staff respond, submission limit student, limit student progress
#
# Cluster 10 summary: UPVC windows are leaking during heavy rains.  Leaking roofs in academic blocks cause distractions and damage personal belongings | Keywords: occasional class disruption, distraction damage personal, damage personal belonging, personal belonging broken, poor sealing hostel
#
# Cluster 11 summary: The classroom fans are broken and have not been fixed.  The classroom fans are broken and have not been fixed | Keywords: classroom fan broken, fan broken fixed, broken fixed classroom, fixed classroom fan, fan broken
#
# Cluster 12 summary: Frequent power outages affect online classes; no timely updates or solutions from maintenance.  Maintenance requests take weeks to get resolved leading to dissatisfaction | Keywords: frequent power outage, outage affect online, affect online class, online class timely, class timely update
#
# Cluster 13 summary: Repeated complaints about the leaking roof near the basketball court have been ignored.  Some sports events are poorly scheduled leading to conflicts and cancellations | Keywords: repeated complaint leaking, tattered replaced promptly, complaint leaking roof, sport event poorly, event poorly scheduled
#
# Cluster 14 summary: Elevator in the main academic block often breaks down causing inconvenience.  Damage to hostel study room furniture affecting student health and posture | Keywords: posing security risk, elevator main academic, study room furniture, room furniture affecting, cold day hot
#
# Cluster 15 summary: Leaky taps and faucets in hostel washrooms cause water wastage and discomfort.  Unpleasant smell in the basement common room due to stagnant water | Keywords: leaky tap faucet, winter affect comfort, wastage discomfort unpleasant, discomfort unpleasant smell, unpleasant smell basement
#
# Cluster 16 summary: The jogging track surface is uneven and causes injuries to runners frequently.  Broken nets on the cricket pitch reduce the quality of training sessions | Keywords: jogging track surface, quality training session, track surface uneven, injury runner frequently, runner frequently broken
#
# Cluster 17 summary: Incomplete sports gear inventory makes it difficult to conduct official matches. | Keywords: incomplete sport gear, conduct official match, sport gear inventory, gear inventory make, inventory make difficult
#
# Cluster 18 summary: Unhygienic conditions in the laundry area due to delayed cleaning routines.  Unpleasant odors in the hostel basement due to drainage issues | Keywords: unhygienic condition laundry, time peak hour, condition laundry area, delayed cleaning routine, cleaning routine unpleasant
#
# Cluster 19 summary: Delay in posting grades for midterms has created anxiety among students. | Keywords: delay posting grade, posting grade midterm, grade midterm created, midterm created anxiety, delay posting
#
# Cluster 20 summary: The auditorium sound system is outdated causing poor audio quality during events. | Keywords: auditorium sound system, audio quality event, sound system outdated, system outdated causing, outdated causing poor
#
# Cluster 21 summary: Heating systems in the library are insufficient during winter creating an uncomfortable environment.  Heating in the computer lab is faulty causing discomfort to long study sessions | Keywords: long study session, system library insufficient, library insufficient winter, insufficient winter creating, winter creating uncomfortable
#
# Cluster 22 summary: Noise pollution from construction nearby disrupts classes and studies regularly. | Keywords: noise pollution construction, class study regularly, pollution construction nearby, construction nearby disrupts, nearby disrupts class
